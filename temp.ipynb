# %%
import pandas as pd
df = pd.read_csv('form_answers.csv', sep=";")
df
# Out:
#     Client_ID Lesson_Types
# 0           1        0 1 2
# 1           2        2 3 5
# 2           3            1
# 3           4            5
# 4           5            3
# 5           6          1 6
# 6           7          8 3
# 7           8          2 1
# 8           9            3
# 9          10            6
# 10         11            2
# 11         12            4
# 12         13            0
# 13         14          3 2
# 14         15          8 7
# 15         16            3
# 16         17          3 6
# 17         18            2
# 18         19            1
# 19         20            1
# 20         21            8
# 21         22          4 5
# 22         23            7
# 23         24          3 7
# 24         25          4 7
# 25         26        3 5 8
# 26         27            3
# 27         28            1
# 28         29            7
# 29         30            4
# 30         31            5
# 31         32          7 6
# 32         33          2 1
# ...

# %%
print([int(elem) for elem in df['Lesson_Types'].iloc[16].split(sep=" ")])
# Out:
# [3, 6]

# %%
from main import Client
import numpy as np
clients = list()
for index, client in df.iterrows():
    clients.append(Client(client['Client_ID'], [int(elem) for elem in client['Lesson_Types'].split(sep=" ")]))
clients = np.array(clients)

print(clients[2])
print(clients)
# Out:
# id: 3, selected_training: [1]
# ...

# %%
x = ['sjosjod', 9898, 9.9, True]
print(np.array(x))
# Out:
# ['sjosjod' '9898' '9.9' 'True']
